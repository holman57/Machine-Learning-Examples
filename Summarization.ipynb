# %% [markdown]
# <a href="https://colab.research.google.com/github/holman57/Machine-Learning-Examples/blob/master/Summarization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers
# !pip install torch --upgrade

# %%
from transformers import pipeline

# %%
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

# %%
import pandas as pd

# %%
wiki = pd.read_html("https://en.wikipedia.org/wiki/Floating-point_arithmetic")
# Out:
#                         0     1         2            3      4   5  \
# 0                    Type  Bits      Bits         Bits   Bits NaN
# 1                    Type  Sign  Exponent  Significand  Total NaN
# 2    Half (IEEE 754-2008)     1         5           10     16 NaN
# 3                  Single     1         8           23     32 NaN
# 4                  Double     1        11           52     64 NaN
# 5  x86 extended precision     1        15           64     80 NaN
# 6                    Quad     1        15          112    128 NaN
#
#                6               7                         8
# 0  Exponent bias  Bits precision  Number of decimal digits
# 1  Exponent bias  Bits precision  Number of decimal digits
# 2             15              11                      ~3.3
# 3            127              24                      ~7.2
# 4           1023              53                     ~15.9
# 5          16383              64                     ~19.2
# ...

# %%
wiki[2]
# Out:
#                Type  Sign  Exponent  Trailing significand field  Total bits
# 0        FP8 (E4M3)     1         4                           3           8
# 1        FP8 (E5M2)     1         5                           2           8
# 2    Half-precision     1         5                          10          16
# 3          Bfloat16     1         8                           7          16
# 4    TensorFloat-32     1         8                          10          19
# 5  Single-precision     1         8                          23          32

# %%
# !pip install Wikipedia-API

# %%
import wikipediaapi

# %%
wiki_wiki = wikipediaapi.Wikipedia(user_agent='Text Summerazation (Luke@LukeHolman.net)', language='en')
page = wiki_wiki.page('Floating-point_arithmetic')
text = page.summary

# %%
summary = summarizer(text, max_length=60, min_length=15, do_sample=True)

# %%
summary[0]['summary_text']
# Out:
# 'Floating-point arithmetic is arithmetic that represents subsets of real numbers using an integer with a fixed precision. In practice, most floating-point systems use base two, though base ten (decimal floating point) is also common.'

# %%
text = str(page.sections[3])

# %%
sum = summarizer(text, max_length=300, min_length=30, do_sample=False)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-2042b405f92e> in <cell line: 1>()
# ----> 1 sum = summarizer(text, max_length=300, min_length=30, do_sample=False)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     267               ids of the summary.
#     268         """
# --> 269         return super().__call__(*args, **kwargs)
#     270
#     271     def check_inputs(self, input_length: int, min_length: int, max_length: int) -> bool:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text2text_generation.py in __call__(self, *args, **kwargs)
#     165         """
#     166
# --> 167         result = super().__call__(*args, **kwargs)
#     168         if (
#     169             isinstance(args[0], list)
#
# ...

# %%
print(sum[0]['summary_text'])
# Out:
# A number representation specifies some way of encoding a number, usually as a string of digits. In standard mathematical notation, the digit string can be of any length, and the location of the radix point is indicated by placing an explicit "point" character.
